# %%
import pandas as pd

df = pd.read_csv("../data/processed/cleaned_train.csv")
df.head()
# Out:
#    unit  cycle  RUL  max_cycle  op_setting_1  op_setting_2  op_setting_3  \
# 0     1      1  191        192       -0.0007       -0.0004         100.0
# 1     1      2  190        192        0.0019       -0.0003         100.0
# 2     1      3  189        192       -0.0043        0.0003         100.0
# 3     1      4  188        192        0.0007        0.0000         100.0
# 4     1      5  187        192       -0.0019       -0.0002         100.0
#
#    sensor_2  sensor_3  sensor_4  ...  sensor_8  sensor_9  sensor_11  \
# 0    641.82   1589.70   1400.60  ...   2388.06   9046.19      47.47
# 1    642.15   1591.82   1403.14  ...   2388.04   9044.07      47.49
# 2    642.35   1587.99   1404.20  ...   2388.08   9052.94      47.27
# 3    642.35   1582.79   1401.87  ...   2388.11   9049.48      47.13
# 4    642.37   1582.85   1406.22  ...   2388.06   9055.15      47.28
#
#    sensor_12  sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  sensor_21
# ...

# %%
df.columns
# Out:
# Index(['cycle', 'RUL', 'max_cycle', 'op_setting_1', 'op_setting_2',
#        'op_setting_3', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_7',
#        'sensor_8', 'sensor_9', 'sensor_11', 'sensor_12', 'sensor_13',
#        'sensor_14', 'sensor_15', 'sensor_17', 'sensor_20', 'sensor_21'],
#       dtype='object')

# %%
print("Colonnes disponibles :", df.columns.tolist())
# Out:
# Colonnes disponibles : ['cycle', 'RUL', 'max_cycle', 'op_setting_1', 'op_setting_2', 'op_setting_3', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_17', 'sensor_20', 'sensor_21']
